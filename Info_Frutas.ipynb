# %% [markdown]
# <a href="https://colab.research.google.com/github/Bel-93/Streamlit_V1/blob/main/Info_Frutas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 63.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import streamlit

# %%
import pandas
streamlit.header('🍌🥭 Build Your Own Fruit Smoothie 🥝🍇')
my_fruit_list = pandas.read_csv("https://uni-lab-files.s3.us-west-2.amazonaws.com/dabw/fruit_macros.txt")
streamlit.dataframe(my_fruit_list)
# Out:
# DeltaGenerator()

# %%
my_fruit_list
# Out:
#            Fruit         Serving_Size Serving_Gram_Weight  \
# 0          Apple              1 large               242 g
# 1        Avocado           1/5 medium                30 g
# 2         Banana             1 medium               126 g
# 3     Cantaloupe           1/4 medium               134 g
# 4     Grapefruit           1/2 medium               154 g
# 5         Grapes              3/4 cup               126 g
# 6       Honeydew    1/10 medium melon               134 g
# 7      Kiwifruit             2 medium               148 g
# 8          Lemon             1 medium                58 g
# 9           Lime             1 medium                67 g
# 10     Nectarine             1 medium               140 g
# 11        Orange             1 medium               154 g
# 12         Peach             1 medium               147 g
# 13          Pear             1 medium               166 g
# 14     Pineapple             2 slices         3" diameter
# ...

# %%
fruits_selected = streamlit.multiselect("Pick some fruits:", list(my_fruit_list.index))
fruits_to_show = my_fruit_list.loc[fruits_selected]
streamlit.dataframe(fruits_to_show)
# Out:
# DeltaGenerator()

# %%
import requests
from urllib.error import URLError
try:
  fruit_choice = streamlit.text_input('What fruit would you like information about?','Kiwi')
  if not fruit_choice:
    streamlit.error('Please select a fruit to get information')
  else:
    streamlit.write('The user entered ', fruit_choice)
    url = "https://fruityvice.com/api/fruit/"+fruit_choice
    fruityvice_response = requests.get(url)
    fruityvice_normalized = pandas.json_normalize(fruityvice_response.json())
    streamlit.dataframe(fruityvice_normalized)
except URLError as e:
  streamlit.error()
